# %%
import sys
import os
from datetime import datetime
import logging
import pstats

import wandb

import torch
from torch import nn
from pytorch_lightning import Trainer
from pytorch_lightning.callbacks import EarlyStopping, ModelCheckpoint
from pytorch_lightning.loggers import TensorBoardLogger

# %%
print(torch.__version__)
# Out:
# 2.4.1+cu124

# %%
from DataSocket.DatasetMonoFlavourShard import DatasetMonoFlavourShard
from DataSocket.DatasetMultiFlavourShard import DatasetMultiFlavourShard
from DataSocket.DatasetMultiFlavourPart import DatasetMultiFlavourPart
from DataSocket.EnergyRange import EnergyRange
from DataSocket.MaxNDOMFinder import MaxNDOMFinder
from DataSocket.PMTfiedDataModule import PMTfiedDataModule
# fails after 10 sec RuntimeError: operator torchvision::nms does not exist
# re run succeeds, 1.3 sec

# %%
from Model.FlavourClassificationTransformerEncoder import FlavourClassificationTransformerEncoder

# %%
if torch.cuda.is_available():
    num_gpus = torch.cuda.device_count()
    print(f"Number of GPUs available: {num_gpus}")
    for i in range(num_gpus):
        print(f"GPU {i}: {torch.cuda.get_device_name(i)}")
else:
    print("No GPU detected.")
# Out:
# Number of GPUs available: 2
# GPU 0: NVIDIA GeForce RTX 3090
# GPU 1: NVIDIA GeForce RTX 3090

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "1"  # Change to "1" if you want to use the second GPU

# %%
root_dir = "/lustre/hpc/project/icecube/HE_Nu_Aske_Oct2024/PMTfied/Snowstorm/"
NuE_PeV_root = root_dir + "22015/"
NuMu_PeV_root = root_dir + "22012/"
NuTau_PeV_root = root_dir + "22018/"

truth_NuE_PeV_1 = NuE_PeV_root + "truth_1.parquet"
truth_NuMu_PeV_1 = NuMu_PeV_root + "truth_1.parquet"
truth_NuTau_PeV_1 = NuTau_PeV_root + "truth_1.parquet"

PMTfied_NuE_PeV_1 = NuE_PeV_root + "1/"
PMTfied_NuE_PeV_1_1 = PMTfied_NuE_PeV_1 + "PMTfied_1.parquet"

PMTfied_NuMu_PeV_1 = NuMu_PeV_root + "1/"
PMTfied_NuMu_PeV_1_1 = PMTfied_NuMu_PeV_1 + "PMTfied_1.parquet"

PMTfied_NuTau_PeV_1 = NuTau_PeV_root + "1/"
PMTfied_NuTau_PeV_1_1 = PMTfied_NuTau_PeV_1 + "PMTfied_1.parquet"

# %%
maxNDOMFinder_PeV_1_1 = MaxNDOMFinder(
    root_dir=root_dir,
    energy_band=EnergyRange.ER_1_PEV_100_PEV,
    part=1,
    shard=1,
    )

# %%
ds_PeV_1_1 = DatasetMultiFlavourShard(
    root_dir=root_dir,
    energy_band=EnergyRange.ER_1_PEV_100_PEV,
    part=1,
    shard=1,
    max_n_doms=maxNDOMFinder_PeV_1_1(),
    verbosity=1,
    )
# Out:
# ------------- Multi-Flavour Shard (Energy Band: ER_1_PEV_100_PEV, Part: 1, Shard: 1) -------------

# %%
dm_PeV_1_1 = PMTfiedDataModule(
    root_dir=root_dir,
    energy_band=EnergyRange.ER_1_PEV_100_PEV,
    dataset = ds_PeV_1_1,
    batch_size=128,
    num_workers=8,
    verbosity=1,
    )

# %%
# md_transformer_PeV_1_1 = FlavourClassificationTransformerEncoder(
#     d_model=128,
#     n_heads=8,
#     d_f=256,
#     num_layers=3,
#     d_input=32, # the number of PMTfied features
#     num_classes=3, # the number of flavours: NuE, NuMu, NuTau
#     dropout=0.1,
#     learning_rate=1e-5,
#     nan_logger=None,
#     train_logger=None,
#     )

# %%
# current_date = datetime.now().strftime("%Y%m%d")
# current_time = datetime.now().strftime("%H%M%S")

# base_log_dir = os.path.join("logs", current_date)
# os.makedirs(base_log_dir, exist_ok=True)

# base_checkpoint_dir = os.path.join("checkpoints", current_date)
# os.makedirs(base_checkpoint_dir, exist_ok=True)

# # Training log
# train_log_filename = os.path.join(base_log_dir, f"{current_time}_training.log")

# train_logger = logging.getLogger("training")
# train_logger.setLevel(logging.INFO)
# train_handler = logging.FileHandler(train_log_filename)
# train_formatter = logging.Formatter("%(asctime)s - %(levelname)s - %(message)s")
# train_handler.setFormatter(train_formatter)
# train_logger.addHandler(train_handler)

# # NaN log
# nan_log_filename = os.path.join(base_log_dir, f"{current_time}_nan_checks.log")
# nan_logger = logging.getLogger("nan_checks")
# nan_logger.setLevel(logging.INFO)
# nan_handler = logging.FileHandler(nan_log_filename)
# nan_formatter = logging.Formatter("%(asctime)s - %(levelname)s - %(message)s")
# nan_handler.setFormatter(nan_formatter)
# nan_logger.addHandler(nan_handler)

# %%
# tb_logger = TensorBoardLogger(
#     save_dir=base_log_dir,
#     name=f"{current_time}",  # Add time to the logger name
# )

# # Set up the checkpoint callback
# checkpoint_callback = ModelCheckpoint(
#     monitor="val_loss",
#     dirpath=base_checkpoint_dir, 
#     filename=f"{current_time}_transformer-epoch{{epoch:02d}}-val_loss{{val_loss:.2f}}",  # Add time to filename
#     save_top_k=3,
#     mode="min"
# )

# # Set up the early stopping callback
# early_stopping_callback = EarlyStopping(
#     monitor="val_loss",
#     patience=10,
#     verbose=True,
#     mode="min"
# )

# %%
def setup_logger(name: str, log_filename: str, level=logging.INFO) -> logging.Logger:
    logger = logging.getLogger(name)
    logger.setLevel(level)
    
    # Create handler
    handler = logging.FileHandler(log_filename)
    formatter = logging.Formatter("%(asctime)s - %(levelname)s - %(message)s")
    handler.setFormatter(formatter)
    
    # Avoid duplicate handlers
    if not logger.hasHandlers():
        logger.addHandler(handler)
    
    return logger

# %%
def setup_directories(base_dir: str, current_date: str, current_time: str):
    log_dir = os.path.join(base_dir, "logs", current_date)
    checkpoint_dir = os.path.join(base_dir, "checkpoints", current_date)
    
    # Create directories
    os.makedirs(log_dir, exist_ok=True)
    os.makedirs(checkpoint_dir, exist_ok=True)
    
    return {
        "log_dir": log_dir,
        "checkpoint_dir": checkpoint_dir,
        "train_log_file": os.path.join(log_dir, f"{current_time}_training.log"),
        "nan_log_file": os.path.join(log_dir, f"{current_time}_nan_checks.log")
    }

# %%
def setup_callbacks(checkpoint_dir: str, current_time: str):
    checkpoint_callback = ModelCheckpoint(
        monitor="val_loss",
        dirpath=checkpoint_dir,
        filename=f"{current_time}_transformer-epoch{{epoch:02d}}-val_loss{{val_loss:.2f}}",
        save_top_k=3,
        mode="min",
    )

    early_stopping_callback = EarlyStopping(
        monitor="val_loss",
        patience=10,
        verbose=True,
        mode="min",
    )

    return [checkpoint_callback, early_stopping_callback]

# %%
def init_wandb(project_name: str, model_class: nn.Module):
    wandb.init(
        project=project_name,
        config={
            "d_model": model_class.d_model,
            "n_heads": model_class.n_heads,
            "d_f": model_class.d_f,
            "num_layers": model_class.num_layers,
            "d_input": model_class.d_input,
            "num_classes": model_class.num_classes,
            "dropout": model_class.dropout,
            "learning_rate": model_class.learning_rate,
            "epochs": 5,
            "attention": "Scaled Dot-Product",
        },
    )

# %%
def log_training_parameters(logger: logging.Logger, model_class: nn.Module):
    logger.info("Starting training...")
    logger.info(
        "| Parameter       | Value               |\n"
        "|-----------------|---------------------|\n"
        f"| attention       | Scaled Dot-Product |\n"
        f"| d_model         | {model_class.d_model:<15}|\n"
        f"| n_heads         | {model_class.n_heads:<15}|\n"
        f"| d_f             | {model_class.d_f:<15}|\n"
        f"| num_layers      | {model_class.num_layers:<15}|\n"
        f"| d_input         | {model_class.d_input:<15}|\n"
        f"| num_classes     | {model_class.num_classes:<15}|\n"
        f"| dropout         | {model_class.dropout:<15}|\n"
        f"| learning_rate   | {model_class.learning_rate:<15}|\n"
    )

# %%
def build_model(config: dict, nan_logger: logging.Logger, train_logger: logging.Logger):
    model = FlavourClassificationTransformerEncoder(
        d_model=config["d_model"],
        n_heads=config["n_heads"],
        d_f=config["d_f"],
        num_layers=config["num_layers"],
        d_input=config["d_input"],
        num_classes=config["num_classes"],
        dropout=config["dropout"],
        learning_rate=config["learning_rate"],
        nan_logger=nan_logger,
        train_logger=train_logger,
    )
    return model

# %%
def runTraining(base_dir: str, model_config: dict, datamodule: PMTfiedDataModule):
    current_date = datetime.now().strftime("%Y%m%d")
    current_time = datetime.now().strftime("%H%M%S")
    
    
    dirs = setup_directories(base_dir, current_date, current_time)
    
    train_logger = setup_logger("training", dirs["train_log_file"])
    nan_logger = setup_logger("nan_checks", dirs["nan_log_file"])
    
    model_class = build_model(model_config, nan_logger, train_logger)
    # TensorBoard logger
    tb_logger = TensorBoardLogger(
        save_dir=dirs["log_dir"],
        name=f"{current_time}",
    )

    callbacks = setup_callbacks(dirs["checkpoint_dir"], current_time)
    
    # Initialize WandB
    project_name = f"[{current_date}_{current_time}]Neutrino Flavour Classification"
    # init_wandb(project_name, model_class)
    
    # Log training parameters
    log_training_parameters(train_logger, model_class)

    # Set up Trainer
    trainer = Trainer(
        max_epochs=5,
        accelerator="gpu" if torch.cuda.is_available() else "cpu",
        devices=1, # use 2 for GPU or else for CPU
        gradient_clip_val=1.0,
        callbacks=callbacks,
        log_every_n_steps=1,
        logger=tb_logger,
    )
    
    # Start training
    trainer.fit(model_class, datamodule=datamodule)
    
    # Finalize WandB
    wandb.finish()
    return trainer

# %%
# def runTraining(model_class: nn.Module, datamodule: PMTfiedDataModule):
#     wandb.init(
#         project=f"[{current_date}_{current_time}]Neutrino Flavour Classification",
#         config={
#             "d_model": model_class.d_model,
#             "n_heads": model_class.n_heads,
#             "d_f": model_class.d_f,
#             "num_layers": model_class.num_layers,
#             "d_input": model_class.d_input,
#             "num_classes": model_class.num_classes,
#             "dropout": model_class.dropout,
#             "learning_rate": model_class.learning_rate,
#             "epochs": 5,
#             "attention": "Scaled Dot-Product",
#         },
#     )

#     train_logger.info(
#     "| Parameter       | Value               |\n"
#     "|-----------------|---------------------|\n"
#     f"| attention       | Scaled Dot-Product |\n"
#     f"| d_model         | {model_class.d_model:<15}|\n"
#     f"| n_heads         | {model_class.n_heads:<15}|\n"
#     f"| d_f             | {model_class.d_f:<15}|\n"
#     f"| num_layers      | {model_class.num_layers:<15}|\n"
#     f"| d_input         | {model_class.d_input:<15}|\n"
#     f"| num_classes     | {model_class.num_classes:<15}|\n"
#     f"| dropout         | {model_class.dropout:<15}|\n"
#     f"| learning_rate   | {model_class.learning_rate:<15}|\n\n"
#     )
#     train_logger.info("Starting training...")

#     trainer = Trainer(
#         max_epochs=5,
#         accelerator="gpu" if torch.cuda.is_available() else "cpu",
#         devices=1,
#         gradient_clip_val=1.0,
#         callbacks=[checkpoint_callback, early_stopping_callback],
#         log_every_n_steps=1,
#         logger=tb_logger
#     )
#     trainer.fit(model_class, datamodule=datamodule)
    
#     wandb.finish()
#     return trainer

# # trainer = runTraining(model_class)

# %%
config ={
    "d_model": 128,
    "n_heads": 8,
    "d_f": 256,
    "num_layers": 3,
    "d_input": 32,
    "num_classes": 3,
    "dropout": 0.1,
    "learning_rate": 1e-5,
    "epochs": 5,
    "attention": "Scaled Dot-Product",
}

# %%
base = '/groups/icecube/cyan/factory/IceCubeTransformer'

# %%
# trainer = runTraining(base, config, dm_PeV_1_1)

# %%
p = pstats.Stats("profiling_results")
p.strip_dirs().sort_stats("cumulative").print_stats()
# Out:
# Sat Feb  1 14:21:08 2025    profiling_results
#
#          3781577 function calls (3698492 primitive calls) in 54.916 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     302/1    0.001    0.000   54.920   54.920 {built-in method builtins.exec}
#         1    0.001    0.001   54.920   54.920 <string>:1(<module>)
#         1    0.000    0.000   54.919   54.919 TrainingDebuggingYard.py:172(execute)
#         1    0.000    0.000   52.129   52.129 TrainingDebuggingYard.py:127(runTraining)
#         1    0.000    0.000   41.597   41.597 trainer.py:503(fit)
#         1    0.000    0.000   41.597   41.597 call.py:31(_call_and_handle_interrupt)
#         1    0.000    0.000   41.597   41.597 trainer.py:547(_fit_impl)
#         1    0.000    0.000   41.597   41.597 trainer.py:909(_run)
#         1    0.000    0.000   41.282   41.282 trainer.py:1017(_run_stage)
#         1    0.001    0.001   40.951   40.951 fit_loop.py:196(run)
#        50    0.001    0.000   40.545    0.811 fit_loop.py:350(advance)
#        50    0.001    0.000   40.544    0.811 training_epoch_loop.py:135(run)
# 3394/2889    0.003    0.000   20.577    0.007 {built-in method builtins.iter}
#       101    0.000    0.000   20.577    0.204 fetchers.py:102(__iter__)
#       101    0.001    0.000   20.576    0.204 fetchers.py:49(__iter__)
#       101    0.026    0.000   20.566    0.204 combined_loader.py:347(__iter__)
#        50    0.009    0.000   18.772    0.375 training_epoch_loop.py:192(advance)
#       101    0.001    0.000   16.445    0.163 dataloader.py:427(__iter__)
#       101    0.001    0.000   16.444    0.163 dataloader.py:383(_get_iterator)
#       101    0.075    0.001   16.442    0.163 dataloader.py:989(__init__)
#       808    0.034    0.000   15.555    0.019 process.py:110(start)
#       808    0.010    0.000   15.449    0.019 context.py:222(_Popen)
#       808    0.011    0.000   15.439    0.019 context.py:274(_Popen)
#       808    0.013    0.000   15.426    0.019 popen_fork.py:15(__init__)
#       808    0.048    0.000   15.400    0.019 popen_fork.py:62(_launch)
#       808   15.277    0.019   15.295    0.019 {built-in method posix.fork}
#  1061/869    0.003    0.000   12.754    0.015 apply_func.py:23(apply_to_collection)
#       200    0.003    0.000   12.727    0.064 logger_connector.py:89(log_metrics)
#       206    0.001    0.000   12.719    0.062 apply_func.py:70(<dictcomp>)
#        50    0.000    0.000   12.704    0.254 logger_connector.py:156(update_train_step_metrics)
#      5796   12.687    0.002   12.687    0.002 {method 'item' of 'torch._C.TensorBase' objects}
#       100    0.000    0.000   12.682    0.127 apply_func.py:113(convert_tensors_to_scalars)
#       150    0.000    0.000   12.681    0.085 apply_func.py:122(to_item)
#        51    0.002    0.000   11.912    0.234 utilities.py:158(_decorator)
#        51    0.002    0.000   11.906    0.233 evaluation_loop.py:108(run)
#        50    0.001    0.000   11.610    0.232 training_epoch_loop.py:280(on_advance_end)
#        51    0.002    0.000   10.296    0.202 evaluation_loop.py:200(reset)
#        50    0.001    0.000   10.153    0.203 training_epoch_loop.py:176(on_run_start)
#      6501    8.811    0.001    8.811    0.001 {method 'acquire' of '_thread.lock' objects}
#        50    0.000    0.000    8.240    0.165 combined_loader.py:90(__iter__)
#        50    0.001    0.000    8.240    0.165 combined_loader.py:41(__iter__)
#        50    0.000    0.000    8.238    0.165 combined_loader.py:43(<listcomp>)
#        51    0.001    0.000    8.208    0.161 combined_loader.py:151(__iter__)
#        51    0.000    0.000    8.208    0.161 combined_loader.py:170(_load_current_iterator)
#      1041    0.006    0.000    7.798    0.007 threading.py:280(wait)
#       254    0.001    0.000    7.756    0.031 wandb_run.py:364(wrapper)
#       101    0.000    0.000    7.751    0.077 wandb_run.py:418(wrapper)
#         1    0.000    0.000    7.718    7.718 wandb_run.py:4248(finish)
#         1    0.000    0.000    7.718    7.718 wandb_run.py:2086(finish)
#         1    0.000    0.000    7.718    7.718 wandb_run.py:2102(_finish)
#         1    0.000    0.000    7.595    7.595 wandb_run.py:2340(_atexit_cleanup)
#         1    0.000    0.000    7.480    7.480 wandb_run.py:2597(_on_finish)
#      1039    0.004    0.000    7.250    0.007 threading.py:563(wait)
#      14/9    0.000    0.000    7.048    0.783 mailbox.py:249(wait)
#        20    0.000    0.000    7.047    0.352 mailbox.py:128(_get_and_clear)
#        20    0.000    0.000    7.047    0.352 mailbox.py:125(_wait)
#       406    0.003    0.000    6.655    0.016 call.py:294(_call_strategy_hook)
#  4848/101    0.005    0.000    6.208    0.061 module.py:1549(_wrapped_call_impl)
#  4848/101    0.020    0.000    6.208    0.061 module.py:1555(_call_impl)
#       101    0.005    0.000    6.206    0.061 FlavourClassificationTransformerEncoder.py:51(forward)
#       303    0.032    0.000    6.096    0.020 EncoderBlock.py:40(forward)
# 1324/1024    0.014    0.000    5.990    0.006 call.py:137(_call_lightning_module_hook)
#        50    0.001    0.000    5.870    0.117 automatic.py:161(run)
#        50    0.001    0.000    5.866    0.117 automatic.py:243(_optimizer_step)
#        50    0.001    0.000    5.864    0.117 module.py:1277(optimizer_step)
#        50    0.000    0.000    5.864    0.117 optimizer.py:84(step)
#        50    0.000    0.000    5.863    0.117 strategy.py:219(optimizer_step)
#        50    0.001    0.000    5.863    0.117 precision.py:112(optimizer_step)
#        50    0.002    0.000    5.862    0.117 optimizer.py:464(wrapper)
#        50    0.002    0.000    5.857    0.117 optimizer.py:70(_use_grad)
#        50    0.002    0.000    5.854    0.117 adam.py:192(step)
#        50    0.000    0.000    5.765    0.115 precision.py:95(_wrap_closure)
#       150    0.001    0.000    5.448    0.036 _contextlib.py:113(decorate_context)
#        50    0.000    0.000    5.443    0.109 automatic.py:142(__call__)
#        50    0.000    0.000    5.442    0.109 automatic.py:126(closure)
#        50    0.000    0.000    5.179    0.104 automatic.py:305(_training_step)
#        50    0.000    0.000    5.174    0.103 strategy.py:379(training_step)
#        50    0.002    0.000    5.172    0.103 FlavourClassificationTransformerEncoder.py:86(training_step)
#       303    4.976    0.016    5.144    0.017 ScaledDotProductAttention.py:28(forward)
#       101    0.000    0.000    4.161    0.041 dataloader.py:1476(__del__)
#       101    0.008    0.000    4.160    0.041 dataloader.py:1399(_shutdown_workers)
#       808    0.003    0.000    3.898    0.005 process.py:142(join)
#       808    0.004    0.000    3.894    0.005 popen_fork.py:36(wait)
#       808    0.004    0.000    3.876    0.005 connection.py:921(wait)
#       812    0.003    0.000    3.866    0.005 selectors.py:403(select)
#       812    3.855    0.005    3.860    0.005 {method 'poll' of 'select.poll' objects}
#         1    0.000    0.000    2.463    2.463 TrainingDebuggingYard.py:79(init_wandb)
#         1    0.000    0.000    2.462    2.462 wandb_init.py:924(init)
#         1    0.000    0.000    2.131    2.131 TrainingDebuggingYard.py:115(secure_the_area)
#       158    0.001    0.000    2.014    0.013 __init__.py:115(is_available)
#       177    0.000    0.000    2.010    0.011 __init__.py:834(device_count)
#        14    0.000    0.000    2.010    0.144 __init__.py:778(_device_count_nvml)
#        14    2.009    0.144    2.010    0.144 __init__.py:647(_raw_device_count_nvml)
#         1    0.000    0.000    1.455    1.455 wandb_init.py:144(setup)
#        51    0.004    0.000    1.266    0.025 evaluation_loop.py:351(_evaluation_step)
#        51    0.001    0.000    1.172    0.023 strategy.py:400(validation_step)
#        51    0.003    0.000    1.170    0.023 FlavourClassificationTransformerEncoder.py:98(validation_step)
#       105    0.000    0.000    1.022    0.010 threading.py:1028(join)
#       209    0.001    0.000    1.022    0.005 threading.py:1066(_wait_for_tstate_lock)
#         4    0.000    0.000    1.008    0.252 wandb_setup.py:324(setup)
#         4    0.000    0.000    1.008    0.252 wandb_setup.py:309(_setup)
#         4    0.000    0.000    1.008    0.252 wandb_setup.py:298(__init__)
#         1    0.000    0.000    1.008    1.008 wandb_init.py:557(init)
#         1    0.000    0.000    1.007    1.007 wandb_setup.py:87(__init__)
#         1    0.000    0.000    1.001    1.001 backend.py:226(cleanup)
#         1    0.000    0.000    1.001    1.001 interface_shared.py:546(join)
#         1    0.000    0.000    1.001    1.001 router.py:98(join)
#         1    0.000    0.000    0.843    0.843 wandb_setup.py:249(_setup)
#         1    0.000    0.000    0.843    0.843 wandb_setup.py:274(_setup_manager)
#         1    0.000    0.000    0.843    0.843 wandb_manager.py:129(__init__)
#         1    0.000    0.000    0.832    0.832 service.py:252(start)
#         1    0.000    0.000    0.832    0.832 service.py:140(_launch_server)
#         1    0.000    0.000    0.801    0.801 service.py:77(_wait_for_ports)
#         4    0.801    0.200    0.801    0.200 {built-in method time.sleep}
#        45    0.000    0.000    0.633    0.014 __init__.py:1(<module>)
#       909    0.052    0.000    0.571    0.001 context.py:100(Queue)
#       606    0.246    0.000    0.567    0.001 LayerNormalisation.py:17(forward)
#       909    0.049    0.000    0.508    0.001 queues.py:37(__init__)
#       764    0.015    0.000    0.494    0.001 call.py:185(_call_callback_hooks)
#       102    0.001    0.000    0.433    0.004 queue.py:154(get)
#        18    0.000    0.000    0.408    0.023 core.py:1776(read_table)
#         1    0.000    0.000    0.401    0.401 wandb_login.py:283(_login)
#         1    0.000    0.000    0.397    0.397 wandb_login.py:168(login)
#         1    0.000    0.000    0.396    0.396 wandb_login.py:184(_print_logged_in_message)
#         1    0.000    0.000    0.396    0.396 wandb_setup.py:190(_get_username)
#         1    0.000    0.000    0.396    0.396 wandb_setup.py:210(_load_viewer)
#         1    0.000    0.000    0.396    0.396 server.py:29(query_with_timeout)
#         1    0.000    0.000    0.396    0.396 util.py:1182(wrapper)
#      6501    0.010    0.000    0.381    0.000 __init__.py:1436(info)
#         1    0.000    0.000    0.374    0.374 wandb_run.py:2413(_on_start)
#      6515    0.009    0.000    0.369    0.000 __init__.py:1565(_log)
#         1    0.001    0.001    0.364    0.364 interface.py:293(publish_python_packages)
#       322    0.001    0.000    0.363    0.001 util.py:1858(working_set)
#       642    0.001    0.000    0.358    0.001 __init__.py:420(metadata)
#      3233    0.171    0.000    0.354    0.000 synchronize.py:50(__init__)
#    351/12    0.001    0.000    0.332    0.028 <frozen importlib._bootstrap>:1002(_find_and_load)
#    350/11    0.001    0.000    0.332    0.030 <frozen importlib._bootstrap>:967(_find_and_load_unlocked)
#    336/11    0.001    0.000    0.330    0.030 <frozen importlib._bootstrap>:659(_load_unlocked)
#         1    0.000    0.000    0.330    0.330 trainer.py:1034(_run_sanity_check)
#    285/11    0.000    0.000    0.330    0.030 <frozen importlib._bootstrap_external>:844(exec_module)
#        50    0.000    0.000    0.322    0.006 precision.py:83(_after_closure)
#        50    0.000    0.000    0.319    0.006 precision.py:124(_clip_gradients)
#        50    0.000    0.000    0.318    0.006 module.py:1218(configure_gradient_clipping)
#        50    0.001    0.000    0.318    0.006 module.py:1150(clip_gradients)
#      1919    0.015    0.000    0.317    0.000 context.py:65(Lock)
#        50    0.000    0.000    0.316    0.006 precision.py:143(clip_gradients)
#        50    0.001    0.000    0.315    0.006 precision.py:162(clip_grad_by_norm)
#        50    0.002    0.000    0.314    0.006 clip_grad.py:19(_no_grad_wrapper)
#         2    0.000    0.000    0.313    0.157 MaxNDOMFinder.py:17(__call__)
#         2    0.000    0.000    0.313    0.157 MaxNDOMFinder.py:18(<listcomp>)
#         6    0.000    0.000    0.313    0.052 MaxNDOMFinder.py:26(_get_max_n_doms_for_subdirectory)
#         6    0.000    0.000    0.313    0.052 MaxNDOMFinder.py:35(_get_max_n_doms_for_part)
#        50    0.003    0.000    0.311    0.006 clip_grad.py:25(clip_grad_norm_)
#    448/11    0.000    0.000    0.302    0.027 <frozen importlib._bootstrap>:220(_call_with_frames_removed)
#        18    0.001    0.000    0.300    0.017 core.py:1276(__init__)
#      1919    0.014    0.000    0.299    0.000 synchronize.py:161(__init__)
#         1    0.000    0.000    0.292    0.292 dataset.py:18(<module>)
#      51/3    0.000    0.000    0.290    0.097 <frozen importlib._bootstrap_external>:1179(exec_module)
#      51/3    0.011    0.000    0.290    0.097 {built-in method _imp.exec_dynamic}
#       659    0.002    0.000    0.274    0.000 parser.py:59(parsestr)
# 22523/22119    0.019    0.000    0.273    0.000 {built-in method builtins.next}
#       659    0.002    0.000    0.272    0.000 parser.py:41(parse)
#        50    0.271    0.005    0.271    0.005 {built-in method torch._foreach_norm}
#       642    0.001    0.000    0.268    0.000 __init__.py:32(message_from_string)
#         1    0.000    0.000    0.260    0.260 DatasetMultiFlavourShard.py:9(__init__)
#         1    0.000    0.000    0.260    0.260 DatasetMultiFlavourShard.py:49(_collect_shards)
#         3    0.000    0.000    0.260    0.087 DatasetMonoFlavourShard.py:13(__init__)
#      1018    0.004    0.000    0.258    0.000 threading.py:880(start)
#       303    0.112    0.000    0.258    0.001 FFN.py:16(forward)
#        50    0.000    0.000    0.252    0.005 automatic.py:238(backward_fn)
#        50    0.001    0.000    0.250    0.005 strategy.py:191(backward)
#      6515    0.005    0.000    0.247    0.000 __init__.py:1591(handle)
#         8    0.000    0.000    0.245    0.031 api.py:1(<module>)
#        50    0.000    0.000    0.243    0.005 precision.py:52(backward)
#        50    0.000    0.000    0.243    0.005 module.py:1086(backward)
#        50    0.001    0.000    0.243    0.005 _tensor.py:465(backward)
#        50    0.001    0.000    0.242    0.005 __init__.py:183(backward)
#      1087    0.001    0.000    0.242    0.000 feedparser.py:173(feed)
#      6511    0.009    0.000    0.240    0.000 __init__.py:1645(callHandlers)
#         3    0.000    0.000    0.240    0.080 DatasetMonoFlavourShard.py:81(_load_feature_data)
#        50    0.001    0.000    0.239    0.005 graph.py:764(_engine_run_backward)
#        50    0.238    0.005    0.238    0.005 {method 'run_backward' of 'torch._C._EngineBase' objects}
#      1746    0.002    0.000    0.237    0.000 feedparser.py:178(_call_parse)
#        50    0.001    0.000    0.237    0.005 fit_loop.py:365(on_advance_end)
#      1746    0.042    0.000    0.236    0.000 feedparser.py:218(_parsegen)
#      6509    0.007    0.000    0.232    0.000 __init__.py:939(handle)
#      1010    0.005    0.000    0.231    0.000 queues.py:86(put)
#      6501    0.004    0.000    0.216    0.000 __init__.py:1178(emit)
#       909    0.012    0.000    0.214    0.000 queues.py:161(_start_thread)
#       114    0.001    0.000    0.213    0.002 imports.py:162(__bool__)
#       114    0.000    0.000    0.213    0.002 imports.py:154(_check_available)
#         5    0.000    0.000    0.213    0.043 imports.py:128(_check_requirement)
#      6509    0.008    0.000    0.212    0.000 __init__.py:1071(emit)
#         5    0.000    0.000    0.212    0.042 __init__.py:968(require)
#         5    0.000    0.000    0.211    0.042 __init__.py:776(resolve)
#        50    0.000    0.000    0.194    0.004 model_checkpoint.py:317(on_train_epoch_end)
#         6    0.000    0.000    0.194    0.032 PseudoNormaliser.py:11(__call__)
#        51    0.001    0.000    0.180    0.004 evaluation_loop.py:239(on_run_start)
#       321    0.001    0.000    0.180    0.001 __init__.py:447(version)
#         6    0.000    0.000    0.179    0.030 subprocess.py:756(__init__)
#         6    0.001    0.000    0.179    0.030 subprocess.py:1677(_execute_child)
#       285    0.002    0.000    0.177    0.001 <frozen importlib._bootstrap_external>:916(get_code)
#        50    0.000    0.000    0.174    0.003 model_checkpoint.py:368(_save_topk_checkpoint)
#        50    0.000    0.000    0.173    0.003 model_checkpoint.py:698(_save_monitor_checkpoint)
#       557    0.002    0.000    0.172    0.000 std.py:1464(display)
#         6    0.000    0.000    0.171    0.029 model_checkpoint.py:718(_update_best_and_save)
#       808    0.001    0.000    0.171    0.000 dataloader.py:1373(_mark_worker_as_unavailable)
#       506    0.001    0.000    0.168    0.000 std.py:1325(refresh)
#      2020    0.004    0.000    0.166    0.000 linear.py:116(forward)
#         1    0.000    0.000    0.163    0.163 wandb_setup.py:120(_settings_setup)
#         6    0.000    0.000    0.162    0.027 model_checkpoint.py:387(_save_checkpoint)
#         6    0.000    0.000    0.162    0.027 trainer.py:1346(save_checkpoint)
#      2020    0.160    0.000    0.160    0.000 {built-in method torch._C._nn.linear}
#         6    0.000    0.000    0.153    0.026 strategy.py:478(save_checkpoint)
#         6    0.000    0.000    0.153    0.026 torch_io.py:36(save_checkpoint)
#         6    0.000    0.000    0.151    0.025 cloud_io.py:65(_atomic_save)
#         7    0.001    0.000    0.150    0.021 serialization.py:598(save)
#         7    0.067    0.010    0.147    0.021 serialization.py:803(_save)
#      1298    0.130    0.000    0.146    0.000 {built-in method io.open}
#         1    0.000    0.000    0.145    0.145 argparse.py:57(insert_env_defaults)
#      9305    0.145    0.000    0.145    0.000 {method 'flush' of '_io.TextIOWrapper' objects}
#         1    0.000    0.000    0.145    0.145 trainer.py:92(__init__)
#         1    0.000    0.000    0.142    0.142 trainer.py:1006(_teardown)
#       285    0.001    0.000    0.142    0.000 <frozen importlib._bootstrap_external>:1036(get_data)
#      6510    0.008    0.000    0.138    0.000 __init__.py:1060(flush)
#        51    0.000    0.000    0.138    0.003 fit_loop.py:213(setup_data)
#         6    0.107    0.018    0.136    0.023 PseudoNormaliser.py:20(_log10_charge)
#      1328    0.002    0.000    0.134    0.000 wandb_run.py:397(wrapper_fn)
# 2991/1621    0.003    0.000    0.133    0.000 wandb_settings.py:521(value)
# 7800/6663    0.005    0.000    0.130    0.000 wandb_settings.py:1408(__getattribute__)
#      3233    0.011    0.000    0.130    0.000 synchronize.py:114(_make_name)
#        57    0.000    0.000    0.129    0.002 __init__.py:850(_resolve_dist)
#         1    0.000    0.000    0.126    0.126 strategy.py:120(setup_environment)
#         1    0.000    0.000    0.126    0.126 cuda.py:37(setup_device)
#         1    0.000    0.000    0.126    0.126 __init__.py:408(set_device)
#         1    0.126    0.126    0.126    0.126 {built-in method torch._C._cuda_setDevice}
#         3    0.000    0.000    0.125    0.042 __init__.py:1045(__init__)
#         3    0.001    0.000    0.125    0.042 __init__.py:1090(scan)
#     64/40    0.000    0.000    0.124    0.003 {built-in method builtins.__import__}
#   113/107    0.001    0.000    0.123    0.001 __init__.py:284(_lazy_init)
#       7/4    0.000    0.000    0.123    0.031 sentry.py:38(wrapper)
#        13    0.000    0.000    0.123    0.009 internal.py:33(api)
#        13    0.001    0.000    0.123    0.009 internal_api.py:183(__init__)
#        12    0.000    0.000    0.123    0.010 wandb_settings.py:1223(_get_url_query_string)
#        12    0.000    0.000    0.123    0.010 internal.py:97(settings)
#         1    0.000    0.000    0.123    0.123 sentry.py:169(end_session)
#         1    0.000    0.000    0.123    0.123 client.py:815(flush)
#         1    0.000    0.000    0.122    0.122 transport.py:558(flush)
#         1    0.000    0.000    0.122    0.122 worker.py:94(flush)
#         1    0.000    0.000    0.122    0.122 worker.py:106(_wait_flush)
#         2    0.000    0.000    0.122    0.061 worker.py:42(_timed_queue_join)
#       9/3    0.000    0.000    0.121    0.040 __init__.py:455(get_device_properties)
#       4/2    0.000    0.000    0.121    0.061 __init__.py:423(get_device_name)
#         1    0.117    0.117    0.117    0.117 {built-in method torch._C._cuda_init}
#        11    0.000    0.000    0.115    0.010 wandb_settings.py:864(<lambda>)
#        11    0.000    0.000    0.115    0.010 wandb_settings.py:1239(_project_url)
#        12    0.115    0.010    0.115    0.010 {built-in method posix.read}
#         1    0.000    0.000    0.115    0.115 wandb_run.py:2662(_on_final)
#         1    0.000    0.000    0.115    0.115 wandb_run.py:3727(_footer)
#         1    0.000    0.000    0.113    0.113 wandb_run.py:3917(_footer_sync_info)
#        13    0.000    0.000    0.113    0.009 settings.py:20(__init__)
#        26    0.000    0.000    0.109    0.004 settings.py:121(_settings)
#        26    0.000    0.000    0.108    0.004 settings.py:116(_safe_add_section)
#        28    0.107    0.004    0.108    0.004 configparser.py:1206(add_section)
#      3234    0.029    0.000    0.107    0.000 tempfile.py:149(__next__)
#      2168    0.002    0.000    0.107    0.000 utils.py:194(inner)
#        18    0.107    0.006    0.107    0.006 core.py:1420(read)
#         3    0.000    0.000    0.107    0.036 __init__.py:1127(__init__)
#         3    0.000    0.000    0.107    0.036 __init__.py:1170(_open)
#      1228    0.003    0.000    0.107    0.000 redirect.py:644(write)
#   993/987    0.003    0.000    0.105    0.000 __init__.py:2165(find_on_path)
#      1215    0.002    0.000    0.103    0.000 wandb_run.py:2304(<lambda>)
#       152    0.000    0.000    0.101    0.001 fetchers.py:119(__next__)
#       101    0.000    0.000    0.101    0.001 fetchers.py:55(__next__)
#        51    0.001    0.000    0.100    0.002 evaluation_loop.py:284(_on_evaluation_start)
#      1228    0.003    0.000    0.099    0.000 wandb_run.py:1526(_console_raw_callback)
#   652/474    0.001    0.000    0.099    0.000 <frozen importlib._bootstrap>:1033(_handle_fromlist)
#       101    0.001    0.000    0.098    0.001 combined_loader.py:339(__next__)
#        51    0.002    0.000    0.097    0.002 evaluation_loop.py:247(on_run_end)
#         1    0.000    0.000    0.097    0.097 wandb_settings.py:1752(_infer_run_settings_from_environment)
#         2    0.000    0.000    0.096    0.048 gitlib.py:84(root)
#       101    0.004    0.000    0.096    0.001 dataloader.py:625(__next__)
#      1228    0.013    0.000    0.095    0.000 interface.py:676(publish_output_raw)
#         3    0.000    0.000    0.094    0.031 cmd.py:1522(_call_process)
#         3    0.000    0.000    0.094    0.031 cmd.py:1079(execute)
#         2    0.000    0.000    0.094    0.047 generic.py:1(<module>)
#      6515    0.006    0.000    0.091    0.000 __init__.py:1550(makeRecord)
#        51    0.001    0.000    0.089    0.002 tqdm_progress.py:287(on_validation_start)
#         1    0.000    0.000    0.088    0.088 fit_loop.py:409(teardown)
#        50    0.004    0.000    0.087    0.002 tqdm_progress.py:223(init_validation_tqdm)
#         1    0.000    0.000    0.086    0.086 DatasetMultiFlavourShard_Micro.py:9(__init__)
#         1    0.000    0.000    0.086    0.086 DatasetMultiFlavourShard_Micro.py:52(_collect_shards)
#         3    0.000    0.000    0.086    0.029 DatasetMonoFlavourShard_Micro.py:13(__init__)
#      6515    0.038    0.000    0.085    0.000 __init__.py:282(__init__)
#         1    0.000    0.000    0.085    0.085 accelerator_connector.py:75(__init__)
#         2    0.000    0.000    0.085    0.042 fetchers.py:78(teardown)
#         2    0.000    0.000    0.085    0.042 combined_loader.py:361(reset)
#         2    0.000    0.000    0.085    0.042 combined_loader.py:50(reset)
#    135898    0.028    0.000    0.083    0.000 feedparser.py:128(__next__)
#         1    0.000    0.000    0.083    0.083 wandb.py:292(__init__)
#      4646    0.081    0.000    0.081    0.000 {method 'any' of 'torch._C.TensorBase' objects}
#        53    0.001    0.000    0.081    0.002 tqdm_progress.py:40(__init__)
#        54    0.000    0.000    0.080    0.001 __init__.py:2928(requires)
#        54    0.000    0.000    0.080    0.001 __init__.py:3220(_dep_map)
#        17    0.000    0.000    0.080    0.005 __init__.py:3228(_compute_dependencies)
#        53    0.003    0.000    0.079    0.001 std.py:952(__init__)
#         1    0.000    0.000    0.079    0.079 frame.py:1(<module>)
#         2    0.000    0.000    0.076    0.038 TrainingDebuggingYard.py:39(setup_logger)
#       152    0.007    0.000    0.075    0.000 module.py:382(log)
#       285    0.074    0.000    0.074    0.000 {built-in method io.open_code}
#         1    0.000    0.000    0.072    0.072 wandb_run.py:2397(_on_init)
#      1932    0.003    0.000    0.071    0.000 __init__.py:2236(distributions_from_metadata)
#        50    0.000    0.000    0.070    0.001 optimizer.py:147(maybe_fallback)
#       659    0.026    0.000    0.070    0.000 feedparser.py:471(_parse_headers)
#        50    0.002    0.000    0.070    0.001 adam.py:699(adam)
#       500    0.001    0.000    0.070    0.000 std.py:1441(moveto)
#       138    0.070    0.001    0.070    0.001 {built-in method numpy.array}
#       808    0.035    0.000    0.069    0.000 process.py:61(_cleanup)
#         3    0.003    0.001    0.067    0.022 DatasetMonoFlavourShard_Micro.py:87(_load_feature_data)
#      3234    0.010    0.000    0.067    0.000 tempfile.py:152(<listcomp>)
#      6509    0.003    0.000    0.065    0.000 __init__.py:916(format)
#        50    0.000    0.000    0.065    0.001 combined_loader.py:72(__next__)
#      1063    0.003    0.000    0.065    0.000 __init__.py:754(read_text)
#       303    0.002    0.000    0.065    0.000 module.py:336(_call_batch_hook)
#      4652    0.064    0.000    0.064    0.000 {built-in method torch.isnan}
#      1228    0.004    0.000    0.064    0.000 interface_shared.py:76(_publish_output_raw)
#         2    0.000    0.000    0.064    0.032 cmd.py:986(<lambda>)
# 214304/200152    0.033    0.000    0.064    0.000 {built-in method builtins.isinstance}
#        50    0.002    0.000    0.064    0.001 adam.py:440(_multi_tensor_adam)
#       101    0.003    0.000    0.064    0.001 dataloader.py:1085(_reset)
#      1344    0.004    0.000    0.064    0.000 interface_sock.py:49(_publish)
#      6509    0.009    0.000    0.063    0.000 __init__.py:650(format)
#         6    0.061    0.010    0.061    0.010 {built-in method _posixsubprocess.fork_exec}
#         7    0.009    0.001    0.060    0.009 {method 'dump' of '_pickle.Pickler' objects}
#       909    0.004    0.000    0.058    0.000 context.py:85(BoundedSemaphore)
#      1344    0.003    0.000    0.058    0.000 sock_client.py:218(send_record_publish)
#         1    0.000    0.000    0.057    0.057 generic.py:2(<module>)
#     26024    0.032    0.000    0.057    0.000 random.py:343(choice)
#      1717    0.002    0.000    0.055    0.000 dataloader.py:1346(_try_put_index)
#    135898    0.046    0.000    0.055    0.000 feedparser.py:78(readline)
#      1065    0.001    0.000    0.054    0.000 pathlib.py:1262(read_text)
#         1    0.000    0.000    0.054    0.054 strategy.py:525(teardown)
#      1348    0.001    0.000    0.054    0.000 sock_client.py:154(send_server_request)
#       557    0.001    0.000    0.053    0.000 std.py:457(print_status)
#      1348    0.007    0.000    0.053    0.000 sock_client.py:145(_send_message)
#       909    0.001    0.000    0.052    0.000 synchronize.py:144(__init__)
#      4142    0.011    0.000    0.052    0.000 util.py:171(register_after_fork)
#      1018    0.051    0.000    0.051    0.000 {built-in method _thread.start_new_thread}
#       909    0.015    0.000    0.049    0.000 connection.py:520(Pipe)
#       101    0.001    0.000    0.049    0.000 strategy.py:262(batch_to_device)
#     17180    0.014    0.000    0.048    0.000 popen_fork.py:24(poll)
#       506    0.003    0.000    0.047    0.000 std.py:1150(__str__)
#       437    0.001    0.000    0.047    0.000 __init__.py:3237(reqs_for_extra)
#       101    0.000    0.000    0.047    0.000 module.py:354(_apply_batch_transfer_handler)
#      2372    0.002    0.000    0.047    0.000 markers.py:234(evaluate)
#         2    0.000    0.000    0.047    0.023 cuda.py:176(_clear_cuda_memory)
#         1    0.000    0.000    0.047    0.047 cuda.py:80(teardown)
#         3    0.000    0.000    0.047    0.016 memory.py:158(empty_cache)
#         3    0.047    0.016    0.047    0.016 {built-in method torch._C._cuda_emptyCache}
#      3634    0.046    0.000    0.046    0.000 {built-in method posix.stat}
#   290/278    0.002    0.000    0.046    0.000 apply_func.py:71(move_data_to_device)
#      1818    0.042    0.000    0.046    0.000 util.py:186(__init__)
#         1    0.000    0.000    0.046    0.046 training_epoch_loop.py:313(teardown)
#   494/487    0.006    0.000    0.045    0.000 {built-in method builtins.__build_class__}
#        51    0.001    0.000    0.045    0.001 evaluation_loop.py:293(_on_evaluation_model_eval)
#       568    0.004    0.000    0.044    0.000 textwrap.py:414(dedent)
#        59    0.000    0.000    0.044    0.001 __init__.py:3247(<listcomp>)
#         1    0.000    0.000    0.044    0.044 evaluation_loop.py:278(teardown)
#       352    0.002    0.000    0.043    0.000 <frozen importlib._bootstrap>:901(_find_spec)
#         9    0.000    0.000    0.043    0.005 imports.py:47(_habana_available_and_importable)
#         1    0.000    0.000    0.043    0.043 accelerator_connector.py:655(_register_external_accelerators_and_strategies)
#         1    0.000    0.000    0.043    0.043 combined_loader.py:165(reset)
#        51    0.000    0.000    0.042    0.001 evaluation_loop.py:309(_on_evaluation_end)
#      5387    0.003    0.000    0.042    0.000 re.py:289(_compile)
#       110    0.001    0.000    0.042    0.000 rank_zero.py:36(wrapped_fn)
#         4    0.002    0.000    0.042    0.011 wandb_settings.py:1282(__init__)
#         1    0.000    0.000    0.042    0.042 setup.py:144(_log_device_info)
#         1    0.000    0.000    0.042    0.042 combined_loader.py:103(reset)
#         1    0.000    0.000    0.042    0.042 accelerator_connector.py:398(_choose_and_init_cluster_environment)
#         1    0.000    0.000    0.042    0.042 xla.py:85(is_available)
#         1    0.000    0.000    0.042    0.042 xla.py:67(auto_device_count)
#         1    0.000    0.000    0.041    0.041 mpi.py:69(detect)
#   593/581    0.004    0.000    0.041    0.000 apply_func.py:91(batch_to)
#       101    0.001    0.000    0.041    0.000 dataloader.py:1297(_next_data)
#         1    0.000    0.000    0.041    0.041 wandb_init.py:485(_log_setup)
#      1348    0.003    0.000    0.041    0.000 sock_client.py:121(_sendall_with_error_handle)
#      3399    0.001    0.000    0.041    0.000 re.py:250(compile)
#       101    0.001    0.000    0.040    0.000 hooks.py:564(transfer_batch_to_device)
#       352    0.000    0.000    0.040    0.000 <frozen importlib._bootstrap_external>:1415(find_spec)
#       100    0.003    0.000    0.040    0.000 wandb.py:430(log_metrics)
# 9944/9943    0.022    0.000    0.040    0.000 module.py:1731(__setattr__)
#       966    0.003    0.000    0.040    0.000 __init__.py:2755(from_location)
#       352    0.001    0.000    0.040    0.000 <frozen importlib._bootstrap_external>:1383(_get_spec)
#       101    0.001    0.000    0.039    0.000 dataloader.py:1264(_get_data)
#      1209    0.039    0.000    0.039    0.000 {method '__exit__' of '_io._IOBase' objects}
#      4143    0.023    0.000    0.039    0.000 weakref.py:165(__setitem__)
#         1    0.000    0.000    0.039    0.039 call.py:76(_call_setup_hook)
#       101    0.000    0.000    0.038    0.000 dataloader.py:1118(_try_get_data)
#        23    0.000    0.000    0.038    0.002 sre_compile.py:783(compile)
#        50    0.001    0.000    0.038    0.001 tqdm_progress.py:269(on_train_batch_end)
#      3751    0.038    0.000    0.038    0.000 {method 'to' of 'torch._C.TensorBase' objects}
#      1348    0.038    0.000    0.038    0.000 {method 'send' of '_socket.socket' objects}
#       557    0.001    0.000    0.037    0.000 std.py:451(fp_write)
#         1    0.000    0.000    0.037    0.037 wandb_run.py:872(_populate_git_info)
#       459    0.003    0.000    0.037    0.000 <frozen importlib._bootstrap_external>:1514(find_spec)
#       656    0.001    0.000    0.037    0.000 wandb_settings.py:492(__init__)
#       101    0.001    0.000    0.037    0.000 tqdm_progress.py:451(_update_n)
#         1    0.000    0.000    0.036    0.036 gitlib.py:113(last_commit)
#       303    0.036    0.000    0.036    0.000 {built-in method torch._C._nn.scaled_dot_product_attention}
#      1324    0.000    0.000    0.036    0.000 wandb_settings.py:555(_validate)
#       152    0.005    0.000    0.035    0.000 result.py:355(log)
#       909    0.024    0.000    0.035    0.000 queues.py:71(_reset)
#      6501    0.011    0.000    0.034    0.000 __init__.py:582(formatTime)
#       642    0.000    0.000    0.034    0.000 _adapters.py:47(__init__)
#       753    0.001    0.000    0.034    0.000 logger_connector.py:229(metrics)
#        23    0.000    0.000    0.034    0.001 sre_compile.py:622(_code)
#       642    0.001    0.000    0.034    0.000 _adapters.py:64(_repair_headers)
#    198/23    0.001    0.000    0.034    0.001 sre_compile.py:87(_compile)
#         8    0.000    0.000    0.034    0.004 wandb_settings.py:1049(_validate_base_url)
#         2    0.000    0.000    0.033    0.017 symbolic.py:280(_get_object)
#      1018    0.033    0.000    0.033    0.000 {built-in method posix.listdir}
#         2    0.000    0.000    0.033    0.017 array.py:1(<module>)
#       430    0.033    0.000    0.033    0.000 {method 'read' of '_io.BufferedReader' objects}
#         1    0.000    0.000    0.033    0.033 symbolic.py:507(is_valid)
#         2    0.000    0.000    0.033    0.016 base.py:136(new_from_sha)
#         6    0.004    0.001    0.033    0.005 PseudoNormaliser.py:47(_pseudo_normalise_time)
#         2    0.000    0.000    0.033    0.016 db.py:39(info)
#         2    0.000    0.000    0.033    0.016 cmd.py:1666(get_object_header)
#     16384    0.032    0.000    0.033    0.000 {built-in method posix.waitpid}
#         2    0.000    0.000    0.033    0.016 gitlib.py:44(_init_repo)
#         2    0.000    0.000    0.033    0.016 base.py:172(__init__)
#        80    0.032    0.000    0.032    0.000 sre_compile.py:292(_optimize_charset)
#       201    0.003    0.000    0.032    0.000 profiler.py:687(__enter__)
# 31033/31028    0.008    0.000    0.032    0.000 {built-in method builtins.hasattr}
#       100    0.001    0.000    0.032    0.000 wandb_run.py:1665(log)
#        13    0.000    0.000    0.032    0.002 gitlib.py:62(repo)
#        51    0.002    0.000    0.032    0.001 evaluation_loop.py:454(_verify_dataloader_idx_requirement)
#      2540    0.032    0.000    0.032    0.000 {built-in method posix.pipe}
#       361    0.003    0.000    0.032    0.000 signature_utils.py:18(is_param_in_hook_signature)
#         1    0.000    0.000    0.032    0.032 wandb_init.py:359(_enable_logging)
#        51    0.000    0.000    0.031    0.001 combined_loader.py:128(__next__)
#         1    0.000    0.000    0.031    0.031 wandb_settings.py:1669(_infer_settings_from_environment)
#         1    0.000    0.000    0.031    0.031 platform.py:1187(platform)
#         1    0.000    0.000    0.030    0.030 platform.py:796(__iter__)
#         1    0.000    0.000    0.030    0.030 functools.py:973(__get__)
#         1    0.000    0.000    0.030    0.030 platform.py:792(processor)
#         1    0.000    0.000    0.030    0.030 platform.py:743(get)
#         1    0.000    0.000    0.030    0.030 platform.py:760(from_subprocess)
#         1    0.000    0.000    0.030    0.030 subprocess.py:377(check_output)
#         1    0.000    0.000    0.030    0.030 subprocess.py:464(run)
#         2    0.000    0.000    0.030    0.015 cmd.py:662(is_cygwin)
#         2    0.000    0.000    0.030    0.015 util.py:486(is_cygwin_git)
#         2    0.000    0.000    0.030    0.015 util.py:455(_is_cygwin_git)
#         2    0.000    0.000    0.030    0.015 cmd.py:1645(_get_persistent_cmd)
#     24462    0.019    0.000    0.030    0.000 _policybase.py:293(header_source_parse)
#       808    0.017    0.000    0.030    0.000 process.py:80(__init__)
#       201    0.001    0.000    0.029    0.000 _ops.py:1047(__call__)
#         6    0.000    0.000    0.029    0.005 local.py:421(write)
#         8    0.029    0.004    0.029    0.004 {method 'write' of '_io.BufferedWriter' objects}
#      1065    0.001    0.000    0.029    0.000 pathlib.py:1246(open)
#       361    0.006    0.000    0.029    0.000 inspect.py:1129(getfullargspec)
#      1717    0.000    0.000    0.029    0.000 dataloader.py:619(_next_index)
#       201    0.028    0.000    0.028    0.000 {built-in method torch._ops.profiler._record_function_enter_new}
#      2615    0.013    0.000    0.028    0.000 version.py:186(__init__)
#       506    0.012    0.000    0.028    0.000 std.py:464(format_meter)
#       102    0.001    0.000    0.028    0.000 logger.py:105(experiment)
#   959/491    0.006    0.000    0.028    0.000 inspect.py:2246(_signature_from_callable)
#        50    0.001    0.000    0.028    0.001 fit_loop.py:331(on_advance_start)
# 2398/2372    0.004    0.000    0.028    0.000 markers.py:137(_evaluate_markers)
#     29525    0.014    0.000    0.028    0.000 serialization.py:813(persistent_id)
#        51    0.001    0.000    0.028    0.001 tqdm_progress.py:292(on_validation_batch_start)
#       303    0.003    0.000    0.028    0.000 sampler.py:275(__iter__)
#        51    0.001    0.000    0.027    0.001 tqdm_progress.py:323(on_validation_end)
#       102    0.003    0.000    0.027    0.000 wandb.py:372(experiment)
#      1018    0.012    0.000    0.027    0.000 threading.py:802(__init__)
#      3832    0.017    0.000    0.027    0.000 message.py:462(get)
#   932/362    0.003    0.000    0.026    0.000 apply_func.py:84(_apply_to_collection_slow)
#       100    0.002    0.000    0.026    0.000 wandb_run.py:1629(_log)
#      2518    0.002    0.000    0.026    0.000 trainer.py:1642(_results)
#       909    0.002    0.000    0.026    0.000 dropout.py:58(forward)
#      7637    0.026    0.000    0.026    0.000 {method 'sub' of 're.Pattern' objects}
#       151    0.001    0.000    0.025    0.000 std.py:1402(set_postfix)
#        51    0.000    0.000    0.025    0.000 logger_connector.py:144(log_eval_end_metrics)
#       642    0.004    0.000    0.025    0.000 _adapters.py:71(<listcomp>)
#      1454    0.009    0.000    0.025    0.000 sampler.py:153(__iter__)
#         6    0.002    0.000    0.025    0.004 PseudoNormaliser.py:34(_pseudo_normalise_dom_pos)
#       285    0.000    0.000    0.025    0.000 <frozen importlib._bootstrap_external>:645(_compile_bytecode)
#     73506    0.025    0.000    0.025    0.000 {method 'get' of 'dict' objects}
#      8211    0.012    0.000    0.025    0.000 enums.py:81(__eq__)
#       101    0.000    0.000    0.024    0.000 context.py:90(Event)
# 1118/1106    0.000    0.000    0.024    0.000 {method 'extend' of 'list' objects}
#       285    0.024    0.000    0.024    0.000 {built-in method marshal.loads}
#       101    0.000    0.000    0.024    0.000 synchronize.py:323(__init__)
#       909    0.004    0.000    0.024    0.000 functional.py:1279(dropout)
#      1323    0.001    0.000    0.024    0.000 _tensor.py:213(__reduce_ex__)
#       659    0.001    0.000    0.024    0.000 feedparser.py:184(close)
#      1968    0.021    0.000    0.023    0.000 {method 'read' of '_io.TextIOWrapper' objects}
#       101    0.000    0.000    0.023    0.000 std.py:1360(reset)
#         2    0.000    0.000    0.023    0.011 indexing.py:1(<module>)
#       336    0.000    0.000    0.023    0.000 <frozen importlib._bootstrap>:558(module_from_spec)
#       240    0.001    0.000    0.023    0.000 {built-in method builtins.sorted}
#       100    0.001    0.000    0.023    0.000 wandb_run.py:1500(_partial_history_callback)
#      2636    0.002    0.000    0.022    0.000 message.py:564(get_content_type)
#       102    0.001    0.000    0.022    0.000 utilities.py:187(_verify_dataloader_idx_requirement)
#     26024    0.016    0.000    0.022    0.000 random.py:237(_randbelow_with_getrandbits)
#      6515    0.013    0.000    0.022    0.000 __init__.py:1514(findCaller)
#       753    0.003    0.000    0.022    0.000 result.py:476(metrics)
#       167    0.001    0.000    0.022    0.000 __init__.py:3288(__init__)
#     23740    0.002    0.000    0.022    0.000 _adapters.py:65(redent)
# 39352/7663    0.019    0.000    0.021    0.000 module.py:2395(named_modules)
#      1871    0.001    0.000    0.021    0.000 genericpath.py:39(isdir)
#       100    0.004    0.000    0.021    0.000 interface.py:589(publish_partial_history)
# 33492/33398    0.016    0.000    0.021    0.000 {built-in method builtins.getattr}
#       966    0.001    0.000    0.021    0.000 __init__.py:2736(__init__)
#      1323    0.010    0.000    0.021    0.000 _tensor.py:248(_reduce_ex_internal)
#      1309    0.000    0.000    0.021    0.000 <frozen importlib._bootstrap_external>:135(_path_stat)
#        51    0.001    0.000    0.021    0.000 hooks.py:162(on_validation_model_eval)
#      1717    0.005    0.000    0.020    0.000 util.py:205(__call__)
#       957    0.002    0.000    0.020    0.000 storage.py:164(cpu)
#      1113    0.020    0.000    0.020    0.000 {method 'copy_' of 'torch._C.StorageBase' objects}
#      1098    0.001    0.000    0.020    0.000 __init__.py:1422(safe_version)
#      2569    0.002    0.000    0.020    0.000 trainer.py:1564(_active_loop)
#      2363    0.020    0.000    0.020    0.000 threading.py:228(__init__)
#       201    0.003    0.000    0.020    0.000 profiler.py:693(__exit__)
#         3    0.001    0.000    0.019    0.006 DatasetMonoFlavourShard.py:86(_load_truth_data)
#       167    0.000    0.000    0.019    0.000 requirements.py:33(__init__)
#       966    0.002    0.000    0.019    0.000 __init__.py:1116(add)
#       491    0.008    0.000    0.019    0.000 inspect.py:2152(_signature_from_function)
#        50    0.001    0.000    0.019    0.000 model_checkpoint.py:667(_monitor_candidates)
#        58    0.001    0.000    0.019    0.000 {built-in method builtins.print}
#        51    0.000    0.000    0.019    0.000 module.py:2459(eval)
#       101    0.002    0.000    0.019    0.000 functional.py:3014(cross_entropy)
#   2346/51    0.004    0.000    0.019    0.000 module.py:2437(train)
#        50    0.000    0.000    0.019    0.000 hooks.py:158(on_validation_model_zero_grad)
#         3    0.000    0.000    0.019    0.006 arraysetops.py:138(unique)
#       758    0.019    0.000    0.019    0.000 {method 'mean' of 'torch._C.TensorBase' objects}
#        51    0.005    0.000    0.018    0.000 module.py:2500(zero_grad)
#         3    0.001    0.000    0.018    0.006 DatasetMonoFlavourShard_Micro.py:105(_load_truth_data)
#      1087    0.002    0.000    0.018    0.000 feedparser.py:101(push)
#      3045    0.003    0.000    0.018    0.000 __init__.py:2185(dist_factory)
#       101    0.001    0.000    0.018    0.000 module.py:351(_on_before_batch_transfer)
#         3    0.001    0.000    0.018    0.006 arraysetops.py:323(_unique1d)
#       404    0.001    0.000    0.018    0.000 context.py:80(Semaphore)
#        51    0.000    0.000    0.018    0.000 evaluation_loop.py:144(setup_data)
#       909    0.018    0.000    0.018    0.000 {built-in method torch.dropout}
#       101    0.000    0.000    0.018    0.000 std.py:1382(set_description)
#  1400/488    0.003    0.000    0.018    0.000 copy.py:128(deepcopy)
#      1977    0.001    0.000    0.018    0.000 message.py:588(get_content_maintype)
#      7481    0.006    0.000    0.018    0.000 posixpath.py:117(splitext)
#        51    0.000    0.000    0.017    0.000 <frozen importlib._bootstrap_external>:1171(create_module)
#         3    0.017    0.006    0.017    0.006 data.py:92(has_len_all_ranks)
#       847    0.014    0.000    0.017    0.000 __init__.py:227(_releaseLock)
#        51    0.017    0.000    0.017    0.000 {built-in method _imp.create_dynamic}
#         1    0.000    0.000    0.017    0.017 callback_connector.py:47(on_trainer_init)
#         1    0.000    0.000    0.017    0.017 registry.py:26(_load_external_callbacks)
#         1    0.000    0.000    0.017    0.017 metadata.py:572(entry_points)
#       404    0.000    0.000    0.017    0.000 synchronize.py:125(__init__)
#      2372    0.006    0.000    0.017    0.000 markers.py:175(default_environment)
#      6427    0.014    0.000    0.017    0.000 <frozen importlib._bootstrap>:398(parent)
#       322    0.000    0.000    0.017    0.000 metadata.py:577(<genexpr>)
#       101    0.017    0.000    0.017    0.000 {built-in method torch._C._nn.cross_entropy_loss}
#       558    0.007    0.000    0.017    0.000 utils.py:333(_screen_shape_linux)
#       321    0.000    0.000    0.016    0.000 __init__.py:452(entry_points)
#    224/68    0.000    0.000    0.016    0.000 copy.py:226(_deepcopy_dict)
#        50    0.000    0.000    0.016    0.000 tqdm_progress.py:263(on_train_epoch_start)
#       201    0.000    0.000    0.016    0.000 _ops.py:887(__call__)
#        51    0.000    0.000    0.016    0.000 tqdm_progress.py:309(on_validation_batch_end)
#       506    0.004    0.000    0.016    0.000 std.py:1446(format_dict)
#      1056    0.001    0.000    0.016    0.000 result.py:430(_get_cache)
#    205275    0.016    0.000    0.016    0.000 {method 'append' of 'list' objects}
#        50    0.016    0.000    0.016    0.000 {built-in method torch._foreach_sqrt}
#      4174    0.003    0.000    0.015    0.000 trainer.py:1381(training)
#        41    0.000    0.000    0.015    0.000 <frozen importlib._bootstrap_external>:1565(_fill_cache)
#       778    0.003    0.000    0.015    0.000 {built-in method builtins.sum}
#       156    0.004    0.000    0.015    0.000 _tensor.py:83(__deepcopy__)
#       606    0.015    0.000    0.015    0.000 {built-in method torch.sqrt}
#       167    0.000    0.000    0.015    0.000 _parser.py:63(parse_requirement)
#       557    0.001    0.000    0.015    0.000 utils.py:378(disp_len)
#       574    0.015    0.000    0.015    0.000 {method 'findall' of 're.Pattern' objects}
#      3078    0.001    0.000    0.015    0.000 module.py:2233(parameters)
#       101    0.000    0.000    0.014    0.000 context.py:75(Condition)
#        50    0.000    0.000    0.014    0.000 early_stopping.py:186(on_train_epoch_end)
# 42255/42229    0.011    0.000    0.014    0.000 {method 'join' of 'str' objects}
#       101    0.000    0.000    0.014    0.000 synchronize.py:212(__init__)
#       151    0.001    0.000    0.014    0.000 progress_bar.py:177(get_metrics)
#      1748    0.014    0.000    0.014    0.000 {method 'readlines' of '_io._IOBase' objects}
#        50    0.001    0.000    0.014    0.000 early_stopping.py:198(_run_early_stopping_check)
#       303    0.001    0.000    0.014    0.000 activation.py:103(forward)
#      7488    0.007    0.000    0.014    0.000 posixpath.py:140(basename)
#      1772    0.001    0.000    0.014    0.000 re.py:203(sub)
#        51    0.000    0.000    0.014    0.000 evaluation_loop.py:300(_on_evaluation_model_train)
#      3257    0.014    0.000    0.014    0.000 {built-in method posix.close}
#         3    0.014    0.005    0.014    0.005 {method 'sort' of 'numpy.ndarray' objects}
#       102    0.000    0.000    0.014    0.000 logger_connector.py:134(update_eval_epoch_metrics)
#      3078    0.001    0.000    0.014    0.000 module.py:2258(named_parameters)
# 2831/2816    0.002    0.000    0.013    0.000 {built-in method builtins.any}
#       982    0.001    0.000    0.013    0.000 {method 'sort' of 'list' objects}
#      3324    0.002    0.000    0.013    0.000 abc.py:117(__instancecheck__)
#        51    0.002    0.000    0.013    0.000 model_helpers.py:70(capture)
#       557    0.001    0.000    0.013    0.000 utils.py:374(_text_width)
#       105    0.001    0.000    0.013    0.000 std.py:1265(close)
#        10    0.000    0.000    0.013    0.001 call.py:167(_call_lightning_datamodule_hook)
#         1    0.000    0.000    0.013    0.013 wandb_run.py:1566(_set_run_obj)
#      1071    0.001    0.000    0.013    0.000 __init__.py:2786(hashcmp)
#       808    0.009    0.000    0.013    0.000 util.py:433(_flush_std_streams)
#     48435    0.013    0.000    0.013    0.000 {method 'match' of 're.Pattern' objects}
#       270    0.001    0.000    0.013    0.000 _decorators.py:363(decorator)
#       138    0.000    0.000    0.013    0.000 __init__.py:3183(_reload_version)
# ...
#         1    0.000    0.000    0.000    0.000 __init__.py:572(UndefinedVariableError)
#         1    0.000    0.000    0.000    0.000 {method 'difference' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 callback.py:205(on_train_start)
#         1    0.000    0.000    0.000    0.000 wandb_settings.py:1904(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 netrc.py:10(NetrcParseError)
#         1    0.000    0.000    0.000    0.000 stata.py:957(StataParser)
#         1    0.000    0.000    0.000    0.000 _typing.py:282(ReadBuffer)
#         3    0.000    0.000    0.000    0.000 callback.py:70(on_sanity_check_start)
#         1    0.000    0.000    0.000    0.000 _tensor_str.py:256(<listcomp>)
#         1    0.000    0.000    0.000    0.000 wandb_init.py:62(_huggingface_version)
#         1    0.000    0.000    0.000    0.000 pytables.py:99(Constant)
#         1    0.000    0.000    0.000    0.000 ops.py:520(Div)
#         1    0.000    0.000    0.000    0.000 <string>:1(__create_fn__)
#         1    0.000    0.000    0.000    0.000 reporting.py:65(warning_lines)
#         1    0.000    0.000    0.000    0.000 pytables.py:637(TermValue)
#         1    0.000    0.000    0.000    0.000 accelerator_connector.py:380(_set_devices_flag_if_auto_passed)
#         1    0.000    0.000    0.000    0.000 threading.py:1104(name)
#         1    0.000    0.000    0.000    0.000 typing.py:845(__repr__)
#         1    0.000    0.000    0.000    0.000 stata.py:792(StataNonCatValueLabel)
#         1    0.000    0.000    0.000    0.000 readers.py:477(_Fwf_Defaults)
#         1    0.000    0.000    0.000    0.000 dataframe_protocol.py:111(CategoricalDescription)
#         4    0.000    0.000    0.000    0.000 {method '__subclasses__' of 'type' objects}
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:2508(_cumsum_dispatcher)
#         1    0.000    0.000    0.000    0.000 printing.py:499(PrettyDict)
#         1    0.000    0.000    0.000    0.000 checkpoint_io.py:71(teardown)
#         1    0.000    0.000    0.000    0.000 strategy.py:76(accelerator)
#         1    0.000    0.000    0.000    0.000 pytables.py:2850(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 _typing.py:303(WriteExcelBuffer)
#         1    0.000    0.000    0.000    0.000 fit_loop.py:111(min_steps)
#         2    0.000    0.000    0.000    0.000 hooks.py:447(teardown)
#         1    0.000    0.000    0.000    0.000 lr_scheduler.py:1304(<listcomp>)
#         1    0.000    0.000    0.000    0.000 ops.py:1170(SeriesSplitter)
#         1    0.000    0.000    0.000    0.000 accessor.py:196(CachedAccessor)
#         1    0.000    0.000    0.000    0.000 checkpoint_connector.py:280(restore_training_state)
#         1    0.000    0.000    0.000    0.000 envelope.py:104(add_item)
#         4    0.000    0.000    0.000    0.000 calendar.py:53(<lambda>)
#         2    0.000    0.000    0.000    0.000 base.py:42(binsha)
#         1    0.000    0.000    0.000    0.000 multi.py:167(MultiIndexPyIntEngine)
#         1    0.000    0.000    0.000    0.000 base.py:517(__init__)
#         2    0.000    0.000    0.000    0.000 strategy.py:448(restore_checkpoint_after_setup)
#         1    0.000    0.000    0.000    0.000 mailbox.py:240(add_probe)
#         1    0.000    0.000    0.000    0.000 ops.py:613(FuncNode)
#         1    0.000    0.000    0.000    0.000 expr.py:771(PythonExprVisitor)
#         1    0.000    0.000    0.000    0.000 blocks.py:2625(DatetimeLikeBlock)
#         1    0.000    0.000    0.000    0.000 precision.py:157(teardown)
#         1    0.000    0.000    0.000    0.000 wandb_manager.py:99(port)
#         1    0.000    0.000    0.000    0.000 resample.py:2033(TimedeltaIndexResamplerGroupby)
#         1    0.000    0.000    0.000    0.000 base.py:55(_AlreadyWarned)
#         1    0.000    0.000    0.000    0.000 engines.py:107(NumExprEngine)
#         1    0.000    0.000    0.000    0.000 accessors.py:608(CombinedDatetimelikeProperties)
#         1    0.000    0.000    0.000    0.000 selectn.py:75(SelectNSeries)
#         1    0.000    0.000    0.000    0.000 compressors.py:67(LZMAFile)
#         2    0.000    0.000    0.000    0.000 strategy.py:97(precision_plugin)
#         2    0.000    0.000    0.000    0.000 strategy.py:439(process_dataloader)
#         1    0.000    0.000    0.000    0.000 utilities.py:50(_parse_loop_limits)
#         1    0.000    0.000    0.000    0.000 model_summary.py:323(<listcomp>)
#         1    0.000    0.000    0.000    0.000 wandb_settings.py:1494(freeze)
#         1    0.000    0.000    0.000    0.000 _typing.py:298(ReadPickleBuffer)
#         1    0.000    0.000    0.000    0.000 process.py:51(parent_process)
#         2    0.000    0.000    0.000    0.000 base.py:60(size)
#         1    0.000    0.000    0.000    0.000 lazy.py:121(LazySet)
#         1    0.000    0.000    0.000    0.000 __init__.py:313(_CountryTimezoneDict)
#         1    0.000    0.000    0.000    0.000 envelope.py:196(inferred_content_type)
#         1    0.000    0.000    0.000    0.000 format.py:1513(_ExtensionArrayFormatter)
#         1    0.000    0.000    0.000    0.000 checkpoint_connector.py:249(restore_datamodule)
#         1    0.000    0.000    0.000    0.000 {built-in method sys.getdefaultencoding}
#         1    0.000    0.000    0.000    0.000 json_format.py:54(Error)
#         1    0.000    0.000    0.000    0.000 ops.py:1179(FrameSplitter)
#         1    0.000    0.000    0.000    0.000 profiler.py:135(teardown)
#         1    0.000    0.000    0.000    0.000 strategy.py:117(_configure_launcher)
#         1    0.000    0.000    0.000    0.000 progress_bar.py:64(train_description)
#         1    0.000    0.000    0.000    0.000 readers.py:507(_DeprecationConfig)
#         1    0.000    0.000    0.000    0.000 _tzpath.py:170(InvalidTZPathWarning)
#         2    0.000    0.000    0.000    0.000 lazy.py:91(LazyList)
#         2    0.000    0.000    0.000    0.000 lazy.py:144(LazySet)
#         1    0.000    0.000    0.000    0.000 callback_connector.py:142(_configure_timer_callback)
#         1    0.000    0.000    0.000    0.000 {method 'pop' of 'collections.OrderedDict' objects}
#         1    0.000    0.000    0.000    0.000 _version_meson.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 pytables.py:3337(FrameFixed)
#         1    0.000    0.000    0.000    0.000 __init__.py:30(NullFrequencyError)
#         1    0.000    0.000    0.000    0.000 connector.py:557(_convert_precision_to_unified_args)
#         3    0.000    0.000    0.000    0.000 __init__.py:1157(obtain)
#         1    0.000    0.000    0.000    0.000 wandb_config.py:110(_set_artifact_callback)
#         1    0.000    0.000    0.000    0.000 wandb_config.py:113(_set_settings)
#         1    0.000    0.000    0.000    0.000 json_format.py:58(SerializeToJsonError)
#         1    0.000    0.000    0.000    0.000 __init__.py:627(PyperclipWindowsException)
#         1    0.000    0.000    0.000    0.000 _ops.py:442(<listcomp>)
#         1    0.000    0.000    0.000    0.000 sock_client.py:16(SockClientClosedError)
#         1    0.000    0.000    0.000    0.000 strategy.py:561(on_train_end)
#         1    0.000    0.000    0.000    0.000 callback.py:58(setup)
#         1    0.000    0.000    0.000    0.000 {built-in method _json.encode_basestring_ascii}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.globals}
#         1    0.000    0.000    0.000    0.000 format.py:1475(_IntArrayFormatter)
#         1    0.000    0.000    0.000    0.000 _tensor_str.py:190(width)
#         1    0.000    0.000    0.000    0.000 reporting.py:69(error_lines)
#         1    0.000    0.000    0.000    0.000 synchronize.py:142(BoundedSemaphore)
#         1    0.000    0.000    0.000    0.000 synchronize.py:159(Lock)
#         2    0.000    0.000    0.000    0.000 expr.py:169(_is_type)
#         1    0.000    0.000    0.000    0.000 blocks.py:2633(DatetimeTZBlock)
#         1    0.000    0.000    0.000    0.000 expressions.py:45(set_use_numexpr)
#         1    0.000    0.000    0.000    0.000 __init__.py:18(IntCastingNaNError)
#         1    0.000    0.000    0.000    0.000 hooks.py:37(on_fit_end)
#         1    0.000    0.000    0.000    0.000 hooks.py:44(on_train_start)
#         1    0.000    0.000    0.000    0.000 {method 'isdisjoint' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 __init__.py:411(SettingWithCopyError)
#         1    0.000    0.000    0.000    0.000 __init__.py:641(CSSWarning)
#         1    0.000    0.000    0.000    0.000 logger.py:79(log_graph)
#         2    0.000    0.000    0.000    0.000 {method 'isascii' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 service_sock.py:26(_get_sock_client)
#         1    0.000    0.000    0.000    0.000 port_file.py:47(sock_port)
#         1    0.000    0.000    0.000    0.000 indexing.py:2589(_iAtIndexer)
#         1    0.000    0.000    0.000    0.000 __init__.py:372(_CountryNameDict)
#         1    0.000    0.000    0.000    0.000 tz.py:1818(_get_supported_offset)
#         3    0.000    0.000    0.000    0.000 __init__.py:2156(find_nothing)
#         1    0.000    0.000    0.000    0.000 dataclasses.py:959(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 version.py:98(InvalidVersion)
#         1    0.000    0.000    0.000    0.000 __init__.py:128(InvalidVersion)
#         1    0.000    0.000    0.000    0.000 profiler.py:52(summary)
#         1    0.000    0.000    0.000    0.000 strategy.py:545(on_train_start)
#         1    0.000    0.000    0.000    0.000 synchronize.py:184(RLock)
#         1    0.000    0.000    0.000    0.000 exceptions.py:11(Error)
#         1    0.000    0.000    0.000    0.000 exceptions.py:15(UnknownTimeZoneError)
#         1    0.000    0.000    0.000    0.000 hooks.py:30(on_fit_start)
#         2    0.000    0.000    0.000    0.000 dataclasses.py:767(_hash_set_none)
#         1    0.000    0.000    0.000    0.000 internal.py:92(apply)
#         1    0.000    0.000    0.000    0.000 service.py:31(ServiceStartProcessError)
#         1    0.000    0.000    0.000    0.000 config.py:109(OptionError)
#         1    0.000    0.000    0.000    0.000 checkpoint_connector.py:311(restore_callbacks)
#         1    0.000    0.000    0.000    0.000 parsing.py:41(<listcomp>)
#         1    0.000    0.000    0.000    0.000 pytables.py:401(UnaryOp)
#         1    0.000    0.000    0.000    0.000 blocks.py:2599(NumericBlock)
#         1    0.000    0.000    0.000    0.000 dtypes.py:149(CategoricalDtypeType)
#         1    0.000    0.000    0.000    0.000 _common.py:164(ZoneInfoNotFoundError)
#         1    0.000    0.000    0.000    0.000 hooks.py:47(on_train_end)
#         1    0.000    0.000    0.000    0.000 mailbox.py:345(enable_keepalive)
#         1    0.000    0.000    0.000    0.000 port_file.py:51(is_valid)
#         1    0.000    0.000    0.000    0.000 pytables.py:394(JointConditionBinOp)
#         1    0.000    0.000    0.000    0.000 __init__.py:72(UnsupportedFunctionCall)
#         1    0.000    0.000    0.000    0.000 __init__.py:143(DtypeWarning)
#         1    0.000    0.000    0.000    0.000 __init__.py:433(SettingWithCopyWarning)
#         1    0.000    0.000    0.000    0.000 __init__.py:687(IncompatibilityWarning)
#         1    0.000    0.000    0.000    0.000 trainer.py:1476(min_epochs)
#         1    0.000    0.000    0.000    0.000 hooks.py:420(setup)
#         1    0.000    0.000    0.000    0.000 accessors.py:541(PeriodProperties)
#         1    0.000    0.000    0.000    0.000 __init__.py:693(AttributeConflictWarning)
#         1    0.000    0.000    0.000    0.000 __init__.py:793(NoBufferPresent)
#         1    0.000    0.000    0.000    0.000 precision.py:39(connect)
#         1    0.000    0.000    0.000    0.000 trainer.py:1472(max_epochs)
#         1    0.000    0.000    0.000    0.000 module.py:936(configure_callbacks)
#         1    0.000    0.000    0.000    0.000 anomaly_mode.py:116(__enter__)
#         1    0.000    0.000    0.000    0.000 wandb_manager.py:187(_get_service)
#         1    0.000    0.000    0.000    0.000 tz.py:627(<listcomp>)
#         1    0.000    0.000    0.000    0.000 precision.py:48(convert_module)
#         1    0.000    0.000    0.000    0.000 subprocess.py:1014(__enter__)
#         1    0.000    0.000    0.000    0.000 json_format.py:62(ParseError)
#         1    0.000    0.000    0.000    0.000 service.py:255(sock_port)
#         1    0.000    0.000    0.000    0.000 expr.py:319(add_ops)
#         1    0.000    0.000    0.000    0.000 std.py:1301(<lambda>)
#         1    0.000    0.000    0.000    0.000 service_sock.py:23(get_transport)
#         1    0.000    0.000    0.000    0.000 __init__.py:398(epoch)
#         1    0.000    0.000    0.000    0.000 __init__.py:417(dev)
#         1    0.000    0.000    0.000    0.000 strategy.py:252(_setup_model)
#         1    0.000    0.000    0.000    0.000 tempfile.py:835(__enter__)
#         1    0.000    0.000    0.000    0.000 service.py:43(ServiceStartPortError)
#         1    0.000    0.000    0.000    0.000 blocks.py:2605(ObjectBlock)
#         1    0.000    0.000    0.000    0.000 context.py:213(_check_available)
#         1    0.000    0.000    0.000    0.000 service.py:37(ServiceStartTimeoutError)
#         1    0.000    0.000    0.000    0.000 pytables.py:2670(GenericDataIndexableCol)
#         1    0.000    0.000    0.000    0.000 __init__.py:46(PerformanceWarning)
#         1    0.000    0.000    0.000    0.000 __init__.py:598(IndexingError)
#         1    0.000    0.000    0.000    0.000 config_init.py:656(register_plotting_backend_cb)
#         1    0.000    0.000    0.000    0.000 exceptions.py:38(InvalidTimeError)
#         1    0.000    0.000    0.000    0.000 exceptions.py:42(AmbiguousTimeError)
#         1    0.000    0.000    0.000    0.000 exceptions.py:53(NonExistentTimeError)
#         1    0.000    0.000    0.000    0.000 __init__.py:367(DataError)
#         1    0.000    0.000    0.000    0.000 __init__.py:198(EmptyDataError)
#         1    0.000    0.000    0.000    0.000 __init__.py:311(NumbaUtilError)
#         1    0.000    0.000    0.000    0.000 __init__.py:383(SpecificationError)
#         1    0.000    0.000    0.000    0.000 __init__.py:455(ChainedAssignmentError)
#         1    0.000    0.000    0.000    0.000 __init__.py:553(NumExprClobberingError)
#         1    0.000    0.000    0.000    0.000 __init__.py:619(PyperclipException)
#         1    0.000    0.000    0.000    0.000 __init__.py:662(PossibleDataLossError)
#         1    0.000    0.000    0.000    0.000 __init__.py:769(CategoricalConversionWarning)
#         1    0.000    0.000    0.000    0.000 __init__.py:783(LossySetitemError)
#         1    0.000    0.000    0.000    0.000 __init__.py:799(InvalidComparison)
#         1    0.000    0.000    0.000    0.000 _python_dispatch.py:212(<listcomp>)
#         1    0.000    0.000    0.000    0.000 nanops.py:57(set_use_bottleneck)
#         1    0.000    0.000    0.000    0.000 __init__.py:91(UnsortedIndexError)
#         1    0.000    0.000    0.000    0.000 __init__.py:118(ParserError)
#         1    0.000    0.000    0.000    0.000 __init__.py:328(DuplicateLabelError)
#         1    0.000    0.000    0.000    0.000 __init__.py:347(InvalidIndexError)
#         1    0.000    0.000    0.000    0.000 __init__.py:674(ClosedFileError)
#         1    0.000    0.000    0.000    0.000 __init__.py:714(DatabaseError)
#         1    0.000    0.000    0.000    0.000 __init__.py:727(PossiblePrecisionLoss)
#         1    0.000    0.000    0.000    0.000 __init__.py:742(ValueLabelTypeMismatch)
#         1    0.000    0.000    0.000    0.000 __init__.py:754(InvalidColumnName)
#         1    0.000    0.000    0.000    0.000 {built-in method torch.is_anomaly_check_nan_enabled}
#         1    0.000    0.000    0.000    0.000 __init__.py:212(ParserWarning)
#         1    0.000    0.000    0.000    0.000 __init__.py:253(MergeError)
#         1    0.000    0.000    0.000    0.000 _python_dispatch.py:229(<listcomp>)
#         1    0.000    0.000    0.000    0.000 strategy.py:68(launcher)
#         1    0.000    0.000    0.000    0.000 __init__.py:403(release)
